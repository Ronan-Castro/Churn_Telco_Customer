# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_json('Dados\Telco-Customer-Churn.json')
data
# Out:
#       customerID Churn                                           customer  \
# 0     0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1     0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2     0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3     0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4     0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# ...          ...   ...                                                ...
# 7262  9987-LUTYD    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263  9992-RRAMN   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264  9992-UJOEL    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7265  9993-LHIEB    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7266  9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                   phone  \
# ...

# %%
customer = pd.json_normalize(data.customer)
internet = pd.json_normalize(data.internet)
phone = pd.json_normalize(data.phone)
account = pd.json_normalize(data.account)

# %%
customer['Churn'] = data.Churn

# %%
data1 = pd.concat([customer, internet], axis=1)
data2 = pd.concat([phone, account], axis=1)
data_final = pd.concat([data1, data2], axis=1)

# %%
data_final.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure Churn InternetService  \
# 0  Female              0     Yes        Yes       9    No             DSL
# 1    Male              0      No         No       9    No             DSL
# 2    Male              0      No         No       4   Yes     Fiber optic
# 3    Male              1     Yes         No      13   Yes     Fiber optic
# 4  Female              1     Yes         No       3   Yes     Fiber optic
#
#   OnlineSecurity OnlineBackup DeviceProtection TechSupport StreamingTV  \
# 0             No          Yes               No         Yes         Yes
# 1             No           No               No          No          No
# 2             No           No              Yes          No          No
# 3             No          Yes              Yes          No         Yes
# 4             No           No               No         Yes         Yes
#
#   StreamingMovies PhoneService MultipleLines        Contract PaperlessBilling  \
# ...

# %%
data_final.columns[:]
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure', 'Churn',
#        'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'PhoneService',
#        'MultipleLines', 'Contract', 'PaperlessBilling', 'PaymentMethod',
#        'Charges.Monthly', 'Charges.Total'],
#       dtype='object')

# %%
renomear_coluna ={
    'gender' : 'Gênero',
    'SeniorCitizen' : 'Idoso',
    'Partner' : 'Parceiro',
    'Dependents' : 'Dependentes',
    'tenure' : 'Fidelidade',
    'InternetService' : 'Internet',
    'OnlineSecurity' : 'Segurança Online',
    'OnlineBackup' : 'Backup Online',
    'DeviceProtection' : 'Proteção no Dispositivo',
    'TechSupport' : 'Suporte Técnico',
    'StreamingTV' : 'TV a Cabo',
    'StreamingMovies' : 'Streaming de Filmes',
    'PhoneService' : 'Serviço Telefônico',
    'MultipleLines' : 'Diversas Linhas de Telefone',
    'Contract' : 'Contrato',
    'PaperlessBilling' : 'Fatura Online',
    'PaymentMethod' : 'Método de Pagamento',
    'Charges.Monthly' : 'Despesa Mensal',
    'Charges.Total' : 'Despesa Total'
}

# %%
data_final.rename(columns = renomear_coluna, inplace = True)
data_final['TV a Cabo'].value_counts()
# Out:
# No                     2896
# Yes                    2790
# No internet service    1581
# Name: TV a Cabo, dtype: int64

# %%
renomear_info ={
    'Yes' : 'Sim',
    'No' : 'Não',
    'Fiber optic' : 'Fibra ótica',
    'One year' : 'Um ano',
    'Month-to-month' : 'Mensal',
    'Two year' : 'Dois anos',
    'Electronic check' : 'Débito eletrônico',
    'Mailed check' : 'Pagamento físico',
    'No phone service' : 'Sem serviço telefônico',
    'No internet service' : 'Sem internet',
    'Bank transfer (automatic) ' : 'Automático Débito',
    'Credit transfer (automatic) ' : 'Automático Crédito',
    ' ' : np.nan,
    '' : np.nan
}

# %%
data_final.Churn.value_counts(normalize = True) * 100
# Out:
# No     71.198569
# Yes    25.719004
#         3.082427
# Name: Churn, dtype: float64

# %%
#data_final = data_final[data_final['Churn'] != '']

# %%
data_final.replace(renomear_info, inplace = True)

# %%
empty_val = (data_final.isnull() | data_final.empty | data_final.isna()).sum()
empty_val
# Out:
# Gênero                           0
# Idoso                            0
# Parceiro                         0
# Dependentes                      0
# Fidelidade                       0
# Churn                          224
# Internet                         0
# Segurança Online                 0
# Backup Online                    0
# Proteção no Dispositivo          0
# Suporte Técnico                  0
# TV a Cabo                        0
# Streaming de Filmes              0
# Serviço Telefônico               0
# Diversas Linhas de Telefone      0
# Contrato                         0
# Fatura Online                    0
# Método de Pagamento              0
# Despesa Mensal                   0
# Despesa Total                   11
# dtype: int64

# %%
idx = data_final[data_final["Despesa Total"].isna()].index

# %%
data_final.loc[idx, "Despesa Total"] = data_final.loc[idx, "Despesa Mensal"]
data_final['Despesa Total'] = data_final['Despesa Total'].astype(float)

# %%
data_final.drop(index = data_final[data_final.Churn.isna()].index, inplace = True)
data_final.reset_index(inplace = True, drop = True)

# %%
data_final['Gasto Diário'] = round(data_final['Despesa Total'] / ((data_final['Fidelidade'] + 1) * 30), 2)

# %%
data_final[['Despesa Total', 'Gasto Diário', 'Fidelidade']]
# Out:
#       Despesa Total  Gasto Diário  Fidelidade
# 0            593.30          1.98           9
# 1            542.40          1.81           9
# 2            280.85          1.87           4
# 3           1237.85          2.95          13
# 4            267.40          2.23           3
# ...             ...           ...         ...
# 7038         742.90          1.77          13
# 7039        1873.70          2.72          22
# 7040          92.75          1.03           2
# 7041        4627.65          2.27          67
# 7042        3707.60          1.93          63
#
# [7043 rows x 3 columns]

# %%
data_final
# Out:
#       Gênero  Idoso Parceiro Dependentes  Fidelidade Churn     Internet  \
# 0     Female      0      Sim         Sim           9   Não          DSL
# 1       Male      0      Não         Não           9   Não          DSL
# 2       Male      0      Não         Não           4   Sim  Fibra ótica
# 3       Male      1      Sim         Não          13   Sim  Fibra ótica
# 4     Female      1      Sim         Não           3   Sim  Fibra ótica
# ...      ...    ...      ...         ...         ...   ...          ...
# 7038  Female      0      Não         Não          13   Não          DSL
# 7039    Male      0      Sim         Não          22   Sim  Fibra ótica
# 7040    Male      0      Não         Não           2   Não          DSL
# 7041    Male      0      Sim         Sim          67   Não          DSL
# 7042    Male      0      Sim         Sim          63   Não          DSL
#
#      Segurança Online Backup Online Proteção no Dispositivo  ... TV a Cabo  \
# ...

# %%
data_final.to_json('Dados\BaseLimpa.json')
